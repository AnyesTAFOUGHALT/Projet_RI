# %% [markdown]
# # Ranking Models :

# %%
import pyterrier as pt
if not pt.started():
  pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])
# Out:
# terrier-assemblies 5.9 jar-with-dependencies not found, downloading to /home/djeghali/.pyterrier...
# Done
# PyTerrier 0.10.0 has loaded Terrier 5.9 (built by craigm on 2024-05-02 17:40) and terrier-helper 0.0.8

# %%
# !pip install --upgrade python-terrier
# !pip install --upgrade git+https://github.com/Georgetown-IR-Lab/OpenNIR
# !pip install --upgrade git+https://github.com/terrierteam/pyterrier_t5
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.10.1.tar.gz (110 kB)
#      |████████████████████████████████| 110 kB 3.2 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: chest in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (0.2.3)
# Requirement already satisfied, skipping upgrade: deprecated in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (1.2.14)
# Requirement already satisfied, skipping upgrade: dill in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (0.3.8)
# Requirement already satisfied, skipping upgrade: ir_datasets>=0.3.2 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (0.5.6)
# Requirement already satisfied, skipping upgrade: ir_measures>=0.3.1 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (0.3.3)
# Requirement already satisfied, skipping upgrade: jinja2 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (3.1.3)
# Requirement already satisfied, skipping upgrade: joblib in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (1.3.2)
# Requirement already satisfied, skipping upgrade: matchpy in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (0.5.5)
# Requirement already satisfied, skipping upgrade: more_itertools in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (10.2.0)
# Requirement already satisfied, skipping upgrade: nptyping==1.4.4 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (1.4.4)
# Requirement already satisfied, skipping upgrade: numpy in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (1.24.3)
# Requirement already satisfied, skipping upgrade: pandas in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (2.0.3)
# Requirement already satisfied, skipping upgrade: pyjnius>=1.4.2 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (1.6.1)
# Requirement already satisfied, skipping upgrade: pytrec_eval_terrier>=0.5.3 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (0.5.6)
# Requirement already satisfied, skipping upgrade: requests in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (2.31.0)
# Requirement already satisfied, skipping upgrade: scipy in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (1.10.1)
# Requirement already satisfied, skipping upgrade: statsmodels in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (0.14.1)
# Requirement already satisfied, skipping upgrade: tqdm in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (4.66.1)
# Requirement already satisfied, skipping upgrade: wget in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier) (3.2)
# Requirement already satisfied, skipping upgrade: heapdict in /home/djeghali/.local/lib/python3.8/site-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied, skipping upgrade: wrapt<2,>=1.10 in /home/djeghali/.local/lib/python3.8/site-packages (from deprecated->python-terrier) (1.16.0)
# Requirement already satisfied, skipping upgrade: trec-car-tools>=2.5.4 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied, skipping upgrade: warc3-wet-clueweb09>=0.2.5 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied, skipping upgrade: lz4>=3.1.10 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.3.2->python-terrier) (4.3.3)
# Requirement already satisfied, skipping upgrade: warc3-wet>=0.2.3 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied, skipping upgrade: zlib-state>=0.1.3 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.1.6)
# Requirement already satisfied, skipping upgrade: ijson>=3.1.3 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.3.2->python-terrier) (3.2.3)
# Requirement already satisfied, skipping upgrade: pyautocorpus>=0.1.1 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.1.12)
# Requirement already satisfied, skipping upgrade: unlzw3>=0.2.1 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.2)
# Requirement already satisfied, skipping upgrade: lxml>=4.5.2 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.3.2->python-terrier) (5.1.0)
# Requirement already satisfied, skipping upgrade: beautifulsoup4>=4.4.1 in /usr/lib/python3/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.8.2)
# Requirement already satisfied, skipping upgrade: inscriptis>=2.2.0 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.3.2->python-terrier) (2.5.0)
# Requirement already satisfied, skipping upgrade: pyyaml>=5.3.1 in /usr/lib/python3/dist-packages (from ir_datasets>=0.3.2->python-terrier) (5.3.1)
# Requirement already satisfied, skipping upgrade: cwl-eval>=1.0.10 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_measures>=0.3.1->python-terrier) (1.0.12)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=2.0 in /home/djeghali/.local/lib/python3.8/site-packages (from jinja2->python-terrier) (2.1.5)
# Requirement already satisfied, skipping upgrade: multiset<3.0,>=2.0 in /home/djeghali/.local/lib/python3.8/site-packages (from matchpy->python-terrier) (2.1.1)
# Requirement already satisfied, skipping upgrade: typish>=1.7.0 in /home/djeghali/.local/lib/python3.8/site-packages (from nptyping==1.4.4->python-terrier) (1.9.3)
# Requirement already satisfied, skipping upgrade: pytz>=2020.1 in /home/djeghali/.local/lib/python3.8/site-packages (from pandas->python-terrier) (2023.3.post1)
# Requirement already satisfied, skipping upgrade: tzdata>=2022.1 in /home/djeghali/.local/lib/python3.8/site-packages (from pandas->python-terrier) (2023.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.8.2 in /home/djeghali/.local/lib/python3.8/site-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->python-terrier) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in /home/djeghali/.local/lib/python3.8/site-packages (from requests->python-terrier) (1.26.18)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/djeghali/.local/lib/python3.8/site-packages (from requests->python-terrier) (2024.2.2)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /home/djeghali/.local/lib/python3.8/site-packages (from requests->python-terrier) (3.3.2)
# Requirement already satisfied, skipping upgrade: packaging>=21.3 in /home/djeghali/.local/lib/python3.8/site-packages (from statsmodels->python-terrier) (23.2)
# Requirement already satisfied, skipping upgrade: patsy>=0.5.4 in /home/djeghali/.local/lib/python3.8/site-packages (from statsmodels->python-terrier) (0.5.6)
# Requirement already satisfied, skipping upgrade: cbor>=1.0.0 in /home/djeghali/.local/lib/python3.8/site-packages (from trec-car-tools>=2.5.4->ir_datasets>=0.3.2->python-terrier) (1.0.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->python-terrier) (1.14.0)
# Building wheels for collected packages: python-terrier
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.10.1-py3-none-any.whl size=117271 sha256=bfb7d5987590db31f403ccbcf5659dc389c3c5e79d1d99f712877e20d5ca2b6c
#   Stored in directory: /home/djeghali/.cache/pip/wheels/53/d0/3a/e88dab262a56583e45b905256acb2d6c047593cba5a3266eab
# Successfully built python-terrier
# Installing collected packages: python-terrier
#   Attempting uninstall: python-terrier
#     Found existing installation: python-terrier 0.10.0
#     Uninstalling python-terrier-0.10.0:
#       Successfully uninstalled python-terrier-0.10.0
# Successfully installed python-terrier-0.10.1
# Collecting git+https://github.com/Georgetown-IR-Lab/OpenNIR
#   Cloning https://github.com/Georgetown-IR-Lab/OpenNIR to /tmp/pip-req-build-mb2w4hk5
#   Running command git clone -q https://github.com/Georgetown-IR-Lab/OpenNIR /tmp/pip-req-build-mb2w4hk5
# Collecting Cython>=0.29.2
#   Downloading Cython-3.0.10-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 3.9 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: Unidecode>=1.0.22 in /usr/lib/python3/dist-packages (from OpenNIR==0.1.0) (1.1.1)
# Collecting beautifulsoup4>=4.9.3
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 9.5 MB/s eta 0:00:01
# Collecting cached-property>=1.5.1
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Collecting colorlog==4.0.2
#   Downloading colorlog-4.0.2-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied, skipping upgrade: gensim>=3.7.3 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (4.3.2)
# Requirement already satisfied, skipping upgrade: html5lib>=1.0.1 in /usr/lib/python3/dist-packages (from OpenNIR==0.1.0) (1.0.1)
# Requirement already satisfied, skipping upgrade: ir_datasets>=0.2.0 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (0.5.6)
# Requirement already satisfied, skipping upgrade: ir_measures>=0.2.1 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (0.3.3)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0.2 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (3.7.5)
# Requirement already satisfied, skipping upgrade: nltk>=3.4.5 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (3.8.1)
# Requirement already satisfied, skipping upgrade: pyjnius>=1.2.1 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (1.6.1)
# Collecting python-ternary>=1.0.6
#   Downloading python_ternary-1.0.8-py3-none-any.whl (18 kB)
# Collecting pytools>=2018.5.2
#   Downloading pytools-2024.1.2-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.3 MB/s eta 0:00:01
# Collecting pytorch-pretrained-bert==0.6.1
#   Downloading pytorch_pretrained_bert-0.6.1-py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 13.8 MB/s eta 0:00:01
# Collecting pytorch-transformers==1.1.0
#   Downloading pytorch_transformers-1.1.0-py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 6.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pytrec-eval-terrier>=0.5.1 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (0.5.6)
# Requirement already satisfied, skipping upgrade: seaborn>=0.9.0 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (0.13.2)
# Requirement already satisfied, skipping upgrade: sqlitedict>=1.6.0 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (2.1.0)
# Requirement already satisfied, skipping upgrade: terminaltables>=3.1.0 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (3.1.10)
# Requirement already satisfied, skipping upgrade: tokenizers>=0.1.1 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (0.15.2)
# Requirement already satisfied, skipping upgrade: torch>=1.3.1 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (2.2.0)
# Requirement already satisfied, skipping upgrade: tqdm>=4.38.0 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (4.66.1)
# Requirement already satisfied, skipping upgrade: transformers>=4.3.3 in /home/djeghali/.local/lib/python3.8/site-packages (from OpenNIR==0.1.0) (4.38.2)
# Requirement already satisfied, skipping upgrade: soupsieve>1.2 in /usr/lib/python3/dist-packages (from beautifulsoup4>=4.9.3->OpenNIR==0.1.0) (1.9.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.7.0 in /home/djeghali/.local/lib/python3.8/site-packages (from gensim>=3.7.3->OpenNIR==0.1.0) (1.10.1)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /home/djeghali/.local/lib/python3.8/site-packages (from gensim>=3.7.3->OpenNIR==0.1.0) (6.4.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.18.5 in /home/djeghali/.local/lib/python3.8/site-packages (from gensim>=3.7.3->OpenNIR==0.1.0) (1.24.3)
# Requirement already satisfied, skipping upgrade: warc3-wet-clueweb09>=0.2.5 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.5)
# Requirement already satisfied, skipping upgrade: trec-car-tools>=2.5.4 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (2.6)
# Requirement already satisfied, skipping upgrade: pyyaml>=5.3.1 in /usr/lib/python3/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (5.3.1)
# Requirement already satisfied, skipping upgrade: warc3-wet>=0.2.3 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.3)
# Requirement already satisfied, skipping upgrade: ijson>=3.1.3 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (3.2.3)
# Requirement already satisfied, skipping upgrade: lz4>=3.1.10 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (4.3.3)
# Requirement already satisfied, skipping upgrade: zlib-state>=0.1.3 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.1.6)
# Requirement already satisfied, skipping upgrade: inscriptis>=2.2.0 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (2.5.0)
# Requirement already satisfied, skipping upgrade: unlzw3>=0.2.1 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.2)
# Requirement already satisfied, skipping upgrade: lxml>=4.5.2 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (5.1.0)
# Requirement already satisfied, skipping upgrade: requests>=2.22.0 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (2.31.0)
# Requirement already satisfied, skipping upgrade: pyautocorpus>=0.1.1 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.1.12)
# Requirement already satisfied, skipping upgrade: cwl-eval>=1.0.10 in /home/djeghali/.local/lib/python3.8/site-packages (from ir_measures>=0.2.1->OpenNIR==0.1.0) (1.0.12)
# Requirement already satisfied, skipping upgrade: contourpy>=1.0.1 in /home/djeghali/.local/lib/python3.8/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (1.1.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/djeghali/.local/lib/python3.8/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (0.12.1)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /home/djeghali/.local/lib/python3.8/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (23.2)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /home/djeghali/.local/lib/python3.8/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (10.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7 in /home/djeghali/.local/lib/python3.8/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (2.8.2)
# Requirement already satisfied, skipping upgrade: importlib-resources>=3.2.0; python_version < "3.10" in /home/djeghali/.local/lib/python3.8/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (6.1.0)
# Requirement already satisfied, skipping upgrade: fonttools>=4.22.0 in /home/djeghali/.local/lib/python3.8/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (4.43.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/djeghali/.local/lib/python3.8/site-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (1.4.5)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (2.4.6)
# Requirement already satisfied, skipping upgrade: joblib in /home/djeghali/.local/lib/python3.8/site-packages (from nltk>=3.4.5->OpenNIR==0.1.0) (1.3.2)
# Requirement already satisfied, skipping upgrade: regex>=2021.8.3 in /home/djeghali/.local/lib/python3.8/site-packages (from nltk>=3.4.5->OpenNIR==0.1.0) (2023.12.25)
# Requirement already satisfied, skipping upgrade: click in /home/djeghali/.local/lib/python3.8/site-packages (from nltk>=3.4.5->OpenNIR==0.1.0) (8.1.7)
# Requirement already satisfied, skipping upgrade: typing-extensions>=4.0; python_version < "3.11" in /home/djeghali/.local/lib/python3.8/site-packages (from pytools>=2018.5.2->OpenNIR==0.1.0) (4.11.0)
# Collecting platformdirs>=2.2.0
#   Downloading platformdirs-4.2.1-py3-none-any.whl (17 kB)
# Requirement already satisfied, skipping upgrade: boto3 in /home/djeghali/.local/lib/python3.8/site-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.34.96)
# Requirement already satisfied, skipping upgrade: sentencepiece in /home/djeghali/.local/lib/python3.8/site-packages (from pytorch-transformers==1.1.0->OpenNIR==0.1.0) (0.2.0)
# Requirement already satisfied, skipping upgrade: pandas>=1.2 in /home/djeghali/.local/lib/python3.8/site-packages (from seaborn>=0.9.0->OpenNIR==0.1.0) (2.0.3)
# Requirement already satisfied, skipping upgrade: huggingface_hub<1.0,>=0.16.4 in /home/djeghali/.local/lib/python3.8/site-packages (from tokenizers>=0.1.1->OpenNIR==0.1.0) (0.21.4)
# Requirement already satisfied, skipping upgrade: sympy in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (1.12)
# Requirement already satisfied, skipping upgrade: nvidia-nccl-cu12==2.19.3; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (2.19.3)
# Requirement already satisfied, skipping upgrade: nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.0.106)
# Requirement already satisfied, skipping upgrade: nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.105)
# Requirement already satisfied, skipping upgrade: jinja2 in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (3.1.3)
# Requirement already satisfied, skipping upgrade: networkx in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (2.8.8)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.105)
# Requirement already satisfied, skipping upgrade: fsspec in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (2024.2.0)
# Requirement already satisfied, skipping upgrade: nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (8.9.2.26)
# Requirement already satisfied, skipping upgrade: triton==2.2.0; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (2.2.0)
# Requirement already satisfied, skipping upgrade: nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.3.1)
# Requirement already satisfied, skipping upgrade: nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (10.3.2.106)
# Requirement already satisfied, skipping upgrade: nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (11.4.5.107)
# Requirement already satisfied, skipping upgrade: filelock in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (3.13.1)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.105)
# Requirement already satisfied, skipping upgrade: nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (11.0.2.54)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.105)
# Requirement already satisfied, skipping upgrade: safetensors>=0.4.1 in /home/djeghali/.local/lib/python3.8/site-packages (from transformers>=4.3.3->OpenNIR==0.1.0) (0.4.2)
# Requirement already satisfied, skipping upgrade: cbor>=1.0.0 in /home/djeghali/.local/lib/python3.8/site-packages (from trec-car-tools>=2.5.4->ir_datasets>=0.2.0->OpenNIR==0.1.0) (1.0.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/djeghali/.local/lib/python3.8/site-packages (from requests>=2.22.0->ir_datasets>=0.2.0->OpenNIR==0.1.0) (2024.2.2)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.22.0->ir_datasets>=0.2.0->OpenNIR==0.1.0) (2.8)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /home/djeghali/.local/lib/python3.8/site-packages (from requests>=2.22.0->ir_datasets>=0.2.0->OpenNIR==0.1.0) (3.3.2)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in /home/djeghali/.local/lib/python3.8/site-packages (from requests>=2.22.0->ir_datasets>=0.2.0->OpenNIR==0.1.0) (1.26.18)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.2->OpenNIR==0.1.0) (1.14.0)
# Requirement already satisfied, skipping upgrade: zipp>=3.1.0; python_version < "3.10" in /home/djeghali/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib>=3.0.2->OpenNIR==0.1.0) (3.17.0)
# Requirement already satisfied, skipping upgrade: s3transfer<0.11.0,>=0.10.0 in /home/djeghali/.local/lib/python3.8/site-packages (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (0.10.1)
# Requirement already satisfied, skipping upgrade: botocore<1.35.0,>=1.34.96 in /home/djeghali/.local/lib/python3.8/site-packages (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.34.96)
# Requirement already satisfied, skipping upgrade: jmespath<2.0.0,>=0.7.1 in /home/djeghali/.local/lib/python3.8/site-packages (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.0.1)
# Requirement already satisfied, skipping upgrade: tzdata>=2022.1 in /home/djeghali/.local/lib/python3.8/site-packages (from pandas>=1.2->seaborn>=0.9.0->OpenNIR==0.1.0) (2023.3)
# Requirement already satisfied, skipping upgrade: pytz>=2020.1 in /home/djeghali/.local/lib/python3.8/site-packages (from pandas>=1.2->seaborn>=0.9.0->OpenNIR==0.1.0) (2023.3.post1)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /home/djeghali/.local/lib/python3.8/site-packages (from sympy->torch>=1.3.1->OpenNIR==0.1.0) (1.3.0)
# Requirement already satisfied, skipping upgrade: nvidia-nvjitlink-cu12 in /home/djeghali/.local/lib/python3.8/site-packages (from nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64"->torch>=1.3.1->OpenNIR==0.1.0) (12.3.101)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=2.0 in /home/djeghali/.local/lib/python3.8/site-packages (from jinja2->torch>=1.3.1->OpenNIR==0.1.0) (2.1.5)
# Building wheels for collected packages: OpenNIR
#   Building wheel for OpenNIR (setup.py) ... done
#   Created wheel for OpenNIR: filename=OpenNIR-0.1.0-py3-none-any.whl size=55851474 sha256=3a870715c65f712108ea61463b0d071a903d331c57697952a5c76e28ada09cd2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fchqusa4/wheels/08/c6/f1/46b4eeeaf8730f89bb1ba3411c665b30fbe2f816e2fa7bc7f8
# Successfully built OpenNIR
# Installing collected packages: Cython, beautifulsoup4, cached-property, colorlog, python-ternary, platformdirs, pytools, pytorch-pretrained-bert, pytorch-transformers, OpenNIR
# Successfully installed Cython-3.0.10 OpenNIR-0.1.0 beautifulsoup4-4.12.3 cached-property-1.5.2 colorlog-4.0.2 platformdirs-4.2.1 python-ternary-1.0.8 pytools-2024.1.2 pytorch-pretrained-bert-0.6.1 pytorch-transformers-1.1.0
# Collecting git+https://github.com/terrierteam/pyterrier_t5
#   Cloning https://github.com/terrierteam/pyterrier_t5 to /tmp/pip-req-build-e08kg596
#   Running command git clone -q https://github.com/terrierteam/pyterrier_t5 /tmp/pip-req-build-e08kg596
# Requirement already satisfied, skipping upgrade: pandas in /home/djeghali/.local/lib/python3.8/site-packages (from pyterrier-t5==0.0.1) (2.0.3)
# Requirement already satisfied, skipping upgrade: python-terrier>=0.5.0 in /home/djeghali/.local/lib/python3.8/site-packages (from pyterrier-t5==0.0.1) (0.10.1)
# Requirement already satisfied, skipping upgrade: sentencepiece>=0.1.95 in /home/djeghali/.local/lib/python3.8/site-packages (from pyterrier-t5==0.0.1) (0.2.0)
# Requirement already satisfied, skipping upgrade: torch in /home/djeghali/.local/lib/python3.8/site-packages (from pyterrier-t5==0.0.1) (2.2.0)
# Requirement already satisfied, skipping upgrade: transformers>=4.0.0 in /home/djeghali/.local/lib/python3.8/site-packages (from pyterrier-t5==0.0.1) (4.38.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.8.2 in /home/djeghali/.local/lib/python3.8/site-packages (from pandas->pyterrier-t5==0.0.1) (2.8.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.20.3; python_version < "3.10" in /home/djeghali/.local/lib/python3.8/site-packages (from pandas->pyterrier-t5==0.0.1) (1.24.3)
# Requirement already satisfied, skipping upgrade: tzdata>=2022.1 in /home/djeghali/.local/lib/python3.8/site-packages (from pandas->pyterrier-t5==0.0.1) (2023.3)
# Requirement already satisfied, skipping upgrade: pytz>=2020.1 in /home/djeghali/.local/lib/python3.8/site-packages (from pandas->pyterrier-t5==0.0.1) (2023.3.post1)
# Requirement already satisfied, skipping upgrade: more-itertools in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (10.2.0)
# Requirement already satisfied, skipping upgrade: matchpy in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.5)
# Requirement already satisfied, skipping upgrade: chest in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.3)
# Requirement already satisfied, skipping upgrade: dill in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.3.8)
# Requirement already satisfied, skipping upgrade: joblib in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.3.2)
# Requirement already satisfied, skipping upgrade: pytrec-eval-terrier>=0.5.3 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.6)
# Requirement already satisfied, skipping upgrade: tqdm in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.66.1)
# Requirement already satisfied, skipping upgrade: statsmodels in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.14.1)
# Requirement already satisfied, skipping upgrade: requests in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.31.0)
# Requirement already satisfied, skipping upgrade: scipy in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.10.1)
# Requirement already satisfied, skipping upgrade: wget in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.2)
# Requirement already satisfied, skipping upgrade: deprecated in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.2.14)
# Requirement already satisfied, skipping upgrade: nptyping==1.4.4 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.4.4)
# Requirement already satisfied, skipping upgrade: ir-measures>=0.3.1 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.3.3)
# Requirement already satisfied, skipping upgrade: jinja2 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.1.3)
# Requirement already satisfied, skipping upgrade: ir-datasets>=0.3.2 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.6)
# Requirement already satisfied, skipping upgrade: pyjnius>=1.4.2 in /home/djeghali/.local/lib/python3.8/site-packages (from python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.6.1)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (12.1.105)
# Requirement already satisfied, skipping upgrade: filelock in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (3.13.1)
# Requirement already satisfied, skipping upgrade: nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (11.0.2.54)
# Requirement already satisfied, skipping upgrade: sympy in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (1.12)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (12.1.105)
# Requirement already satisfied, skipping upgrade: nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (11.4.5.107)
# Requirement already satisfied, skipping upgrade: nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (8.9.2.26)
# Requirement already satisfied, skipping upgrade: networkx in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (2.8.8)
# Requirement already satisfied, skipping upgrade: triton==2.2.0; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (2.2.0)
# Requirement already satisfied, skipping upgrade: nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (12.1.105)
# Requirement already satisfied, skipping upgrade: fsspec in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (2024.2.0)
# Requirement already satisfied, skipping upgrade: nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (10.3.2.106)
# Requirement already satisfied, skipping upgrade: nvidia-nccl-cu12==2.19.3; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (2.19.3)
# Requirement already satisfied, skipping upgrade: typing-extensions>=4.8.0 in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (4.11.0)
# Requirement already satisfied, skipping upgrade: nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (12.1.3.1)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (12.1.105)
# Requirement already satisfied, skipping upgrade: nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64" in /home/djeghali/.local/lib/python3.8/site-packages (from torch->pyterrier-t5==0.0.1) (12.1.0.106)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /home/djeghali/.local/lib/python3.8/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (23.2)
# Requirement already satisfied, skipping upgrade: huggingface-hub<1.0,>=0.19.3 in /home/djeghali/.local/lib/python3.8/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.21.4)
# Requirement already satisfied, skipping upgrade: regex!=2019.12.17 in /home/djeghali/.local/lib/python3.8/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (2023.12.25)
# Requirement already satisfied, skipping upgrade: tokenizers<0.19,>=0.14 in /home/djeghali/.local/lib/python3.8/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.15.2)
# Requirement already satisfied, skipping upgrade: safetensors>=0.4.1 in /home/djeghali/.local/lib/python3.8/site-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (0.4.2)
# Requirement already satisfied, skipping upgrade: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers>=4.0.0->pyterrier-t5==0.0.1) (5.3.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->pyterrier-t5==0.0.1) (1.14.0)
# Requirement already satisfied, skipping upgrade: multiset<3.0,>=2.0 in /home/djeghali/.local/lib/python3.8/site-packages (from matchpy->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.1.1)
# Requirement already satisfied, skipping upgrade: heapdict in /home/djeghali/.local/lib/python3.8/site-packages (from chest->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.1)
# Requirement already satisfied, skipping upgrade: patsy>=0.5.4 in /home/djeghali/.local/lib/python3.8/site-packages (from statsmodels->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.5.6)
# Requirement already satisfied, skipping upgrade: urllib3<3,>=1.21.1 in /home/djeghali/.local/lib/python3.8/site-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.26.18)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in /home/djeghali/.local/lib/python3.8/site-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.3.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/djeghali/.local/lib/python3.8/site-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2024.2.2)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.8)
# Requirement already satisfied, skipping upgrade: wrapt<2,>=1.10 in /home/djeghali/.local/lib/python3.8/site-packages (from deprecated->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.16.0)
# Requirement already satisfied, skipping upgrade: typish>=1.7.0 in /home/djeghali/.local/lib/python3.8/site-packages (from nptyping==1.4.4->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.9.3)
# Requirement already satisfied, skipping upgrade: cwl-eval>=1.0.10 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-measures>=0.3.1->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.12)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=2.0 in /home/djeghali/.local/lib/python3.8/site-packages (from jinja2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.1.5)
# Requirement already satisfied, skipping upgrade: inscriptis>=2.2.0 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.5.0)
# Requirement already satisfied, skipping upgrade: beautifulsoup4>=4.4.1 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.12.3)
# Requirement already satisfied, skipping upgrade: lz4>=3.1.10 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (4.3.3)
# Requirement already satisfied, skipping upgrade: warc3-wet-clueweb09>=0.2.5 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.5)
# Requirement already satisfied, skipping upgrade: trec-car-tools>=2.5.4 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (2.6)
# Requirement already satisfied, skipping upgrade: lxml>=4.5.2 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (5.1.0)
# Requirement already satisfied, skipping upgrade: warc3-wet>=0.2.3 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.3)
# Requirement already satisfied, skipping upgrade: pyautocorpus>=0.1.1 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.1.12)
# Requirement already satisfied, skipping upgrade: zlib-state>=0.1.3 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.1.6)
# Requirement already satisfied, skipping upgrade: ijson>=3.1.3 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (3.2.3)
# Requirement already satisfied, skipping upgrade: unlzw3>=0.2.1 in /home/djeghali/.local/lib/python3.8/site-packages (from ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (0.2.2)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /home/djeghali/.local/lib/python3.8/site-packages (from sympy->torch->pyterrier-t5==0.0.1) (1.3.0)
# Requirement already satisfied, skipping upgrade: nvidia-nvjitlink-cu12 in /home/djeghali/.local/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64"->torch->pyterrier-t5==0.0.1) (12.3.101)
# Requirement already satisfied, skipping upgrade: soupsieve>1.2 in /usr/lib/python3/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.9.5)
# Requirement already satisfied, skipping upgrade: cbor>=1.0.0 in /home/djeghali/.local/lib/python3.8/site-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier>=0.5.0->pyterrier-t5==0.0.1) (1.0.0)
# Building wheels for collected packages: pyterrier-t5
#   Building wheel for pyterrier-t5 (setup.py) ... done
#   Created wheel for pyterrier-t5: filename=pyterrier_t5-0.0.1-py3-none-any.whl size=10445 sha256=36edc8f58cf92755154e09f5e17515ab1125a943e6bfd775caf2c6f27447e55c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l10q7tua/wheels/df/0e/b8/67c142a794ec6d2c9b8fd5725d0c8c3f1ac32e520478dcafa4
# Successfully built pyterrier-t5
# Installing collected packages: pyterrier-t5
# Successfully installed pyterrier-t5-0.0.1

# %%
import onir_pt
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %% [markdown]
# ## Récupération des index :

# %%
indexer = pt.DFIndexer("./index_3docs", overwrite=True)         # Définition du format de données (DFIndexer())
index_ref = indexer.index(docs_df["text"], docs_df["docno"])
index = pt.IndexFactory.of(index_ref)
